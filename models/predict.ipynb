# %%
import json
import numpy as np
# %pip uninstall tensorflow
# %pip install tensorflow==2.19
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# Load class indices
with open('class_indices.json', 'r') as f:
    class_indices = json.load(f)
    idx_to_class = {v: k for k, v in class_indices.items()}

# Load the trained model
model = load_model('plant_disease_model.h5')

def predict_plant_disease(img_path):
    """
    Predicts the class of a plant disease from an image file.
    Args:
        img_path (str): Path to the image file.
    Returns:
        str: Predicted class name.
        float: Prediction confidence (probability).
    """
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = x / 255.0
    preds = model.predict(x)
    pred_idx = np.argmax(preds[0])
    pred_class = idx_to_class[pred_idx]
    confidence = float(preds[0][pred_idx])
    return pred_class, confidence

print(predict_plant_disease("D:\My PC Folder\Downloads\download (2).jpg"))
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the 'd:\Ish\Projects\PlantCare\models\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: tensorflow==2.19 in d:\ish\projects\plantcare\models\venv\lib\site-packages (2.19.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (3.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (3.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (2.32.4)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (0.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (5.29.5)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (0.6.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (2.0.2)
# Requirement already satisfied: six>=1.12.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (1.17.0)
# Requirement already satisfied: tensorboard~=2.19.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (2.19.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (18.1.1)
# Requirement already satisfied: setuptools in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (49.2.1)
# Requirement already satisfied: h5py>=3.11.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (3.14.0)
# Requirement already satisfied: packaging in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (25.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (4.14.1)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (25.2.10)
# Requirement already satisfied: wrapt>=1.11.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (1.17.2)
# Requirement already satisfied: absl-py>=1.0.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (2.3.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (1.74.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (1.6.3)
# Requirement already satisfied: keras>=3.5.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (3.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1; python_version < "3.12" in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorflow==2.19) (0.31.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19) (2025.7.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19) (3.10)
# Requirement already satisfied: markdown>=2.6.8 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow==2.19) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow==2.19) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow==2.19) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.19) (0.45.1)
# Requirement already satisfied: rich in d:\ish\projects\plantcare\models\venv\lib\site-packages (from keras>=3.5.0->tensorflow==2.19) (14.1.0)
# Requirement already satisfied: optree in d:\ish\projects\plantcare\models\venv\lib\site-packages (from keras>=3.5.0->tensorflow==2.19) (0.17.0)
# Requirement already satisfied: namex in d:\ish\projects\plantcare\models\venv\lib\site-packages (from keras>=3.5.0->tensorflow==2.19) (0.1.0)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in d:\ish\projects\plantcare\models\venv\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.19.0->tensorflow==2.19) (8.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow==2.19) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow==2.19) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow==2.19) (2.19.2)
# Requirement already satisfied: zipp>=3.20 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard~=2.19.0->tensorflow==2.19) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in d:\ish\projects\plantcare\models\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.19) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 get_ipython().run_line_magic('pip', 'uninstall tensorflow')
#       4 get_ipython().run_line_magic('pip', 'install tensorflow==2.19')
# ----> 5 from tensorflow.keras.models import load_model
#       6 from tensorflow.keras.preprocessing import image
#       8 # Load class indices
#
# File d:\Ish\Projects\PlantCare\models\venv\lib\site-packages\tensorflow\__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File d:\Ish\Projects\PlantCare\models\venv\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# File d:\Ish\Projects\PlantCare\models\venv\lib\site-packages\tensorflow\_api\v2\__internal__\autograph\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.autograph namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert # line: 493
#
# File d:\Ish\Projects\PlantCare\models\venv\lib\site-packages\tensorflow\python\autograph\core\ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File d:\Ish\Projects\PlantCare\models\venv\lib\site-packages\tensorflow\python\autograph\utils\__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File d:\Ish\Projects\PlantCare\models\venv\lib\site-packages\tensorflow\python\autograph\utils\context_managers.py:19
#      15 """Various context managers."""
#      17 import contextlib
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#
# File d:\Ish\Projects\PlantCare\models\venv\lib\site-packages\tensorflow\python\framework\ops.py:5929
#    5923   except LookupError:
#    5924     return None
#    5927 def get_to_proto_function(
#    5928     collection_name,
# -> 5929 ) -> Optional[Callable[[Any], message.Message]]:
#    5930   """Returns the to_proto function for collection_name."""
#    5931   try:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\typing.py:243, in _tp_cache.<locals>.inner(*args, **kwds)
#     241 except TypeError:
#     242     pass  # All real errors (not unhashable args) are raised below.
# --> 243 return func(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\typing.py:316, in _SpecialForm.__getitem__(self, parameters)
#     314 @_tp_cache
#     315 def __getitem__(self, parameters):
# --> 316     return self._getitem(self, parameters)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\typing.py:433, in Optional(self, parameters)
#     428 """Optional type.
#     429
#     430 Optional[X] is equivalent to Union[X, None].
#     431 """
#     432 arg = _type_check(parameters, f"{self} requires a single type.")
# --> 433 return Union[arg, type(None)]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\typing.py:243, in _tp_cache.<locals>.inner(*args, **kwds)
#     241 except TypeError:
#     242     pass  # All real errors (not unhashable args) are raised below.
# --> 243 return func(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\typing.py:316, in _SpecialForm.__getitem__(self, parameters)
#     314 @_tp_cache
#     315 def __getitem__(self, parameters):
# --> 316     return self._getitem(self, parameters)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\typing.py:421, in Union(self, parameters)
#     419 msg = "Union[arg, ...]: each arg must be a type."
#     420 parameters = tuple(_type_check(p, msg) for p in parameters)
# --> 421 parameters = _remove_dups_flatten(parameters)
#     422 if len(parameters) == 1:
#     423     return parameters[0]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\typing.py:215, in _remove_dups_flatten(parameters)
#     213         params.append(p)
#     214 # Weed out strict duplicates, preserving the first of each occurrence.
# --> 215 all_params = set(params)
#     216 if len(all_params) < len(params):
#     217     new_params = []
#
# TypeError: unhashable type: 'list'
